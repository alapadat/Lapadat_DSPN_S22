# %%
#set working directory to where the .csv files are on your computer

setwd("C:/Users/roman/OneDrive/Documents/Python Scripts/Lapadat_DSPN_S22/final_project/pre/asecpub22csv")

#read .csv files
#data  <- read.csv("asec_csv_repwgt_2022.csv")
head(data)



#well OK this is fucking unreadable
# Out:
# Error in setwd("C:/Users/roman/OneDrive/Documents/Python Scripts/Lapadat_DSPN_S22/final_project/pre/asecpub22csv"): cannot change working directory
# Traceback:
#
# 1. setwd("C:/Users/roman/OneDrive/Documents/Python Scripts/Lapadat_DSPN_S22/final_project/pre/asecpub22csv")

# %%
#Fill your enemy's heart with fear. Engage the Tidyverse!
library(tidyverse)

#Tells you how many observations are in the dataset.
count(data)

unique_h_year <- data %>% unique(H_YEAR)
length(unique_h_year)
# Out:
#   n
# 1 152732
# Error in isFALSE(incomparables): object 'H_YEAR' not found
# Traceback:
#
# 1. data %>% unique(H_YEAR)
# 2. unique(., H_YEAR)
# 3. unique.data.frame(., H_YEAR)
# 4. isFALSE(incomparables)

# %% [markdown]
# # Houesholds
#
# ## Universe: All households
#
# ### Broad geographic info
#
# - **GEDIV** - census division of residence (9)
# - **GESTFIPS** - state FIPS code, whatever the fuck that is (56)
#
# ### Metropolitan area info
# - **GTCBSA** - metropolitan area CBSA FIPS code (00460 - 79600)
# - **GTCBSAST** - met area people spend most of their lives in/lives split between cities
# - **GTCBSASZ** - metropolitan area size, defined by CBSA, which tells you the metropolitan area
#
# ### Shelter
# - H_LIVQRT: what type of shelter people have (annoyingly phrased as "living quarters")
#
# ### Family income (interview estimate)
# - HEFAMINC: Family income from basic CPS income screener question.
#
# ### *n* minors
# - HH5TO18: 5-18
#
# ### Income
#
# #### Total income
# - HHINC: total household income
# - HPCTCUT: percentiles
# - HTOP5PCT: top 5%
#
# #### Earnings
# - HEARNVAL: total household earnings  (0, +, -) (3)
# - HINC_SE: own business + self-employed (y/n)
# - HINC_WS: wage and salary (y/n)
#
# ### Disability (any)
# - HDIS_YN
#
# ### Own stock
# - HDIV_YN: own stock year of survey
#
# #### Universe: HDIV_YN = 1
# - HDIVVAL: dividend income
#
# ### Educational assistance
# - HED_YN: educational assistance y/n
#
# #### Universe: HED_YN = 1
# - HEDVAL: how much money from educational assistance?
#
# ### Financial assistance (from friends and family not in household)
# - HFIN_YN
#
# ### Universe: HHOTLUN = 1
#
# #### Food stamps
# - HFDVAL: money received in food stamps
#
# ---
# > I'm going to stop including universes in headers here because I've realized it's stupid.
# ---
#
# ### Gov't assistance
# - HLORENT: is government of any kind helping you pay rent
# - HPEBT_YN: Do you have an EBT card
# - HPUBLIC: public housing y/n
# - HRNUMWIC: # people receiving WIC - Women, Infants, and Children Nutrition Program
# - HRWICYN: was anyone on WIC the prior year?
#
# ## Supplemental poverty measure
#
# - HCHCARE_VAL: child care paid by HH members
# - HECTC_YN: extended child tax credit y/n
# - HEIP_YN: any stimulus payments since 1 aug 2020 y/n
#
# ## Property
# - HPRES_MORT: mortage y/n
# - HPROP_VAL: est. current property value *is it the intervewee estimate or the state or another bodies' estimate?*
#
# ## Health insurance
#
# ### Any health insurance
# - HCOV: last year
# - NOW_HCOV: now
#
# ### Any public coverage
# - HPUB: last year
# - NOW_HPUB: now
#
# ### Any private coverage
# - HPRIV
# - NOW_HPRIV
#
# ### Any Medicaid or other means-tested coverage
# - HMCAID
# - NOW_HMCAID
#
# ### Household imputation status
# - No fucking clue what "imputation" means in a health insurance context because OF COURSE, it's HI jargon ffs
#
#
# ## Universe: H_HHTYPE=1
#
# ### *n* minors
# - HUNDER15: under 15
# - HUNDER18: under 18
#
# ### Payment for shelter
# - H_TENURE: type of payment for shelter (3)
#
# ## Universe: H_HHTYPE = 3
# - H_TYPEBC: by omission, A is included (I think). Type B or C household, which has a number of predictors I could use.

# %% [markdown]
# # Family
#
# ## Income
# ### Total income
# - FPCTCUT: income percentiles
# - FTOT_R: total family income
#
# ### Earnings
# - FINC_FR: own farm and self employed y/n
# - FINC_SE: own business and self employed y/n
# - FINC_WS: wage and salary y/n
# - FSEVAL: Self employment income
#
# ## Poverty
# - FAMLIS: family income: poverty threshold, categorical
# - *return: specific variables I don't understand but are likely useful*
#
# ## Health insurance

# %% [markdown]
# # Person
#
# ## Demographics
# ### Individual Characteristics
# - A_AGE: age, categorical
# - A_ENRLW: enrolled in hs, uni, or college, cat_var
# - **a number of variables that define who this person is to the interviewee**
# - A_FTPT: enrolled in school /  full time, part time / cat
# - **A_HGA: educational attainment**
# - A_HSCOL: enrolled in college/uni
# - A_MARITL: marital status
# - P_STAT: children, armed forces, or civilians (15+) / use this to filter out non-labor force ppl
# - PARENT: parents present / cat
#
# #### War
# - PEAFEVER: serve arm forces / bool
# - PEAFWHN1: when did you serve / cat
#
# #### Certifications
# - PECERT1: any active professional, state, or industry license / bool
# - PECERT2: issued by fed, state, or loc govt / bool
# - PECERT3: is cert req. by ~any job / bool
#
# #### Disorders (?)
# - PEDISDRS: difficulty dressing/bathing / bool
# - PEDISEAR: auditory issues / bool
# - PEDISEYE: severe issues seeing / bool
# - PEDISOUT: difficulty with errands / bool
# - PEDISPHY: difficulty walking/climbing stairs / bool
# - PEDISREM: difficulty ~remembering / bool
#
# ## Basic CPS items
# thanks Census bureau for theis highly informative heading
#
# - A_HRS1: how many hrs worked at all jobs?
# - A_MJIND: major industry
# - A_MJOCC: major occupation recode
# - **PEABSRSN: main reason was absent from work last week (universe ==  PEMLR = 2) / cat**
# - PEIO1COW: class of worker on first job / cat
# - PEIOIND: industry
# - PEIOOCC: occupation
# - **PRDISC: discouraged worker** / cat
# - **PRUNTYPE: why unemployed** / cat
#
# ### Edited earning items
# Thanks for the hard work, this document is FUCKING BRILLIANT and I love it. However, I have a single pressing question: what the fuck is this heading going to tell anyone, you linguistically stulted bastard?!
#
# - A_GRSWK: weekly pre-deduction earnings / quant
# - A_HRSPAY: hourly pay / quant
# - **A_CIVLF: civilian labor force** / bool / index: poverty correlate
# - A_CLSWKR: class of worker / cat / def: employment provider
# - A_EXPLF: **experienced labor force** / bool / def: seek / index: job quality (hnull == high, but as opposed to what?)
# - A_FTLF: **full time labor force** / bool / index: job quality
# - A_NLFLJ: last time worked for pay / cat
# - A_PAYABS: **receiving wages/salary for any time off** / bool / index: job quality
# - A_UNCOV: **union coverage** / bool
# - A_UNMEM: **union member** / bool
# - A_USLFT: 35+ hrs worked per week / bool
# - A_USLHRS: how many hrs/week worked / cat %>% quant
# - A_WKSTAT: **full/part time status** / bool
# - PRNLFSCH: Not in labor force (NiLF/NLF) %>% in school, not in school / bool
# - PRPTREA: why part time %>% usually full time, usually part time / cat
#
# ### Work experience

# %% [markdown]
# ## Pre-hypotheses thought blobs
# >"Poor people are unmotivated", positively FUCK. YOU. Can we tell this story (politely) in statistics? Because FUCK THOSE PEOPLE
# > are gov't assistance programs correlated with shit like the quality of shelter, people going to their jobs, etc.
#
#
# ## Lenses
# >lens: the effect of social factors on individual (person) incomes as an aggregate?
# >
# >lens / narrow: people in the U.S. work force

# %% [markdown]
# # Hypothesis Development
#
# ## Hypothesis 1: Prefix
#
# ### Universes: All households
#
# Grouping total household income (HHINC) and household income quintiles (HPCTCUT) + top 5% of households () **by** GESTFIPS (50 states + 6 territories) and GTCBSA (metropolitan area) + GTCBSAST (metropolitan area/areas people spend most of their lives in), as well as the size of that metropolitan area (GTCBSASZ):
#
# Outcome variables will be impacted: the lower the income, higher the incidence of bad outcomes. The higher the income, the lower the incidence of bad outcomes. The lower the income, the lower the incidence of good outcomes. The higher the outcome, the higher the incidence of good outcomes.
#
# Household == HH
#
# ### Hypothesis 1-A: Income ~ Disorders
#
# Disorders (features = - PEDISDRS: difficulty dressing/bathing / bool, - PEDISEAR: auditory issues / bool, - PEDISEYE: severe issues seeing / bool, - PEDISOUT: difficulty with errands / bool, - PEDISPHY: difficulty walking/climbing stairs / bool, - PEDISREM: difficulty ~remembering / bool).
#
# ### Hypothesis 1-B: HH Income ~ Discouraged worker
# Lower household income correlates to higher rates of discouraged workers (PRDISC).
#
# ### Hypothesis 1-C: HH Income ~ Unemployment
# Lower HH income correlates to higher rates of unemployment and, as poverty increases, people not in labor force, part time for non-economic reasons etc [in the categorical variable unemployment type (PRUNTYPE)]. This is positively correlated to with how many children are in that person's family (universe: all families) and HH. However, I expect that correlation to lessen as we increase in income level and quintiles. I expect no relationship or low statistical significance and little correlation for the top 5% of earners.
#
# #### Reasoning
# Where people live, defined by their state/territory and the metropolitan area/s people live in, as well as the size of those areas, predict disorders. I expect to see a correlation where, if I were to look at the metropolitan areas with the fewest disorders, the wealth of those areas (not in model) would be the underlying factor predicting disorders.
#
# I think this is fairly weak and even redundant, but would provide useful information when we **group people's income by their metropolitan area.** Then it would be no longer redundant and this sentence is moot.
#
# ## Hypothesis 2: Unions ~ better outcomes
#
# Union coverage (A_UNCOV) universally (across all HH and personal income levels) predicts higher positive outcomes v. non-union coverage. Union membership (A_UNMEM) predicts the same, but to a marginally higher degree.
#
# ### Hypothesis 2-A: Unions ~ Disorders
# Follows the same pattern as Hypothesis 1-A, where union coverage and/or membership predict fewer disorders v. non-unionized persons.
#
# ### Hypothesis 2-B: Unions ~ Discouraged workers
# Union representation and membership are negatively correlated to a person being a discouraged worker.
#
# ### Hypothesis 2-C: Unions ~ Unemployment
# Union representation and membership are negatively correlated to a person being unemployed.
#
# ### Hypothesis 2-D: Unions ~ Job-related economic outcomes (Census: "Edited Earning Items")
# Union representation and membership are positively correlated with:
# 1) being in the full-time labor force (A_FTLF)
#
# 2) receiving wages/salary for any time off (A_PAYABS)
#
# 3) working 35+ hours/week (A_USLFT).
#
# I expect to see a difference, where non-union workers (will have to control for lurking variables, do not fully understand what those could be yet, need to add to model) are more overworked than union workers. I expect union workers hours/week worked (A_USLHRS) to plateau after 40-50, and the ceiling for non-union workers should be significantly higher. Will have to adjust for the size differences in union-represented v. non-union represented labor force members, as the total *n* of union-represented members is much lower.
#
# 4) weekly pre-deduction earnings (A_GRSWK)
# 5) income (404 - will seek)
#
# ### Hypothesis 2-E: Unions ~ Poverty
# Union representation and membership are negatively correlated with poverty measures.
# 1) Gov't assistance: (- HLORENT: is government of any kind helping you pay rent, - HPEBT_YN: Do you have an EBT card, - HPUBLIC: public housing y/n, - HRNUMWIC: # people receiving WIC - Women, Infants, and Children Nutrition Program, - HRWICYN: was anyone on WIC the prior year?)
#
# ### Hypothesis 2-F: Unions ~ Housing
# Union representation and membership are positively correlated with higher-quality living quarters (H_LIVQRT), which I will have to define on a spectrum from low-high based on the categories encompassed by the living quarters measure (H_LIVQRT).
#
#
#
# ### Sketch
# Union membership and union representation (separately) correlate to higher rates of income/person and income/family, as well as better outcomes as outlined in Hypothesis 1-A thru C.

# %% [markdown]
# # Final writeup
#
# > Q1: Describe your response (Y) variable(s). Include whether it is (they are) continuous (quantitative) or categorical (qualitative) and the expected probability distribution.
#
# Note: I am afraid that I cannot calculate expected probability distributions at this time, given that I have explored the variables of the dataset to build hypotheses, but have not calculated the summary statistics for the dataset. Please accept my apologies, and if possible, point me to a resource that covers how to calculate expected probability distributions. If not, I am sure I can find a good resource myself :)
#
# Please excuse the presence of Markdown syntax.
#
# ABBREVIATIONS:
# cat == categorical
# quant == quantitative
# pseudoboolean/s == coded 0 = not in universe and 1 = yes, 2 = no
#
# Hypothesis 1-A, Disorders: - PEDISDRS: difficulty dressing/bathing / cat, - PEDISEAR: auditory issues / cat, - PEDISEYE: severe issues seeing / cat, - PEDISOUT: difficulty with errands / cat, - PEDISPHY: difficulty walking/climbing stairs / cat, - PEDISREM: difficulty ~remembering / cat. All variables are pseodoboolean.
#
# Hypothesis 1-B, Discouraged worker: discouraged worker (PRDISC), cat, pseudoboolean
#
# Hypothesis 1-C, Unemployment: reasons for unemployment (PRUNTYPE), cat
#
# Hypothesis 2-A, Disorders: (see above)
# Hypothesis 2-B, Discouraged worker: (see above)
# Hypothesis 2-C, Unemployment: (see above)
#
# Hypothesis 2-D, Job-related economic outcomes: Being in the full-time labor force (A_FTLF), cat / receiving wages/salary for any time off, cat (A_PAYABS) / working 35+ hours/week (A_USLFT), cat / how many hrs/week worked per week, cat %>% quant / weekly pre-deduction earnings, quant / personal income, quant
#
# Hypothesis 2-E, Poverty: - HLORENT: is government of any kind helping you pay rent, cat / - HPEBT_YN: Do you have an EBT card, cat / - HPUBLIC: public housing y/n, cat / - HRNUMWIC: # people receiving WIC - Women, Infants, and Children Nutrition Program, cat/ - HRWICYN: was anyone on WIC the prior year, cat
#
# Hypothesis 2-F, Housing: what type of shelter people have, cat
#
# > Q2: Describe your predictor (X) variable(s). Include whether it is (they are) continuous (quantitative) or categorical (qualitative) and the expected probability distribution
#
# Hypothesis 1: household income, cat / income quintile, cat / top 5% of households, cat // Grouped by: state FIPS code, cat / metropolitan area, cat / and the metropolitan area people spend most of their lives in, cat
#
# Hypothesis 2: union coverage, cat / union membership, cat // Grouped by: household income level, cat (household, households == HH) and personal income level, cat
#
# >Q3: What is your hypothesis (described both in prose form and as specific Y=f(X) models)
#
# I'm going to keep the markdown heading syntax to make traversing this less nightmareish. Let me know if it does not have that effect so I can avoid doing it in the future.
#
# ## Hypothesis 1
#
# Grouping total household income (HHINC) and household income quintiles (HPCTCUT) + top 5% of households (HTOP5PCT) **by** GESTFIPS (50 states + 6 territories) and GTCBSA (metropolitan area) + GTCBSAST (metropolitan area/areas people spend most of their lives in), as well as the size of that metropolitan area (GTCBSASZ):
#
# Outcome variables will be impacted: the lower the income, higher the incidence of bad outcomes. The higher the income, the lower the incidence of bad outcomes. The lower the income, the lower the incidence of good outcomes. The higher the outcome, the higher the incidence of good outcomes.
#
# ### Hypothesis 1-A: Income ~ Disorders
#
# Disorders (features = - PEDISDRS: difficulty dressing/bathing / bool, - PEDISEAR: auditory issues / bool, - PEDISEYE: severe issues seeing / bool, - PEDISOUT: difficulty with errands / bool, - PEDISPHY: difficulty walking/climbing stairs / bool, - PEDISREM: difficulty ~remembering / bool).
#
# Y (difficulty dressing/bathing) = f(total household income)
# Y (difficulty dressing/bathing) = f(household income quintiles)
# Y (difficulty dressing/bathing) = f(top 5% of households)
#
# and so forth for every variable. I have trouble comprehending formula notation, so I could be mistating things.
#
# ### Hypothesis 1-B: HH Income ~ Discouraged worker
# Lower household income correlates to higher rates of discouraged workers (PRDISC).
#
# Y (discouraged worker) = f(total household income)
# Y (discouraged worker) = f(household income quintiles)
# Y (discouraged worker) = f(top 5% of households)
#
# ### Hypothesis 1-C: HH Income ~ Unemployment
# Lower HH income correlates to higher rates of unemployment and, as poverty increases, people not in labor force, part time for non-economic reasons etc [in the categorical variable unemployment type (PRUNTYPE)]. This is positively correlated to with how many children are in that person's family (universe: all families) and HH. However, I expect that correlation to lessen as we increase in income level and quintiles. I expect no relationship or low statistical significance and little correlation for the top 5% of earners.
#
# Y (unemployment type 1) = f(total household income)
# Y (unemployment type 2) = f(total household income)
# Y (unemployment type 3) = f(total household income)
# ...etc...
#
# ## Hypothesis 2: Unions ~ better outcomes
#
# Union coverage (A_UNCOV) universally (across all HH and personal income levels) predicts higher positive outcomes v. non-union coverage. Union membership (A_UNMEM) predicts the same, but to a marginally higher degree.
#
# ### Hypothesis 2-A: Unions ~ Disorders
# Follows the same pattern as Hypothesis 1-A, where union coverage and/or membership predict fewer disorders v. non-unionized persons.
#
# ### Hypothesis 2-B: Unions ~ Discouraged workers
# Union representation and membership are negatively correlated to a person being a discouraged worker.
#
# ### Hypothesis 2-C: Unions ~ Unemployment
# Union representation and membership are negatively correlated to a person being unemployed.
#
# ### Hypothesis 2-D: Unions ~ Job-related economic outcomes (Census: "Edited Earning Items")
# Union representation and membership are positively correlated with:
# 1) being in the full-time labor force (A_FTLF)
#
# Y (A_FTLF) = f(union representation)
# Y (A_FTLF) = f(union membership)
#
# 2) receiving wages/salary for any time off (A_PAYABS)
#
# Y (A_PAYABS) = f(union representation)
# Y (A_PAYABS) = f(union membership)
#
# 3) working 35+ hours/week (A_USLFT).
#
# Y (A_USLFT) = f(union representation)
# Y (A_USLFT) = f(union membership)
#
# 5) I expect to see a difference, where non-union workers (will have to control for lurking variables, do not fully understand what those could be yet, need to add to model) are more overworked than union workers. I expect union workers hours/week worked (A_USLHRS) to plateau after 40-50, and the ceiling for non-union workers should be significantly higher. Will have to adjust for the size differences in union-represented v. non-union represented labor force members, as the total *n* of union-represented members is much lower.
#
# Y (A_USLHRS) = f(union representation)
# Y (A_USLHRS) = f(union membership)
#
# 6) weekly pre-deduction earnings (A_GRSWK)
#
# Y (A_GRSWK) = f(union representation)
# Y (A_GRSWK) = f(union membership)
#
# 7) income (404 - will seek)
#
# Y (income) = f(union representation)
# Y (income) = f(union membership)
#
# ### Hypothesis 2-E: Unions ~ Poverty
# Union representation and membership are negatively correlated with poverty measures.
# 1) Gov't assistance: (- HLORENT: is government of any kind helping you pay rent, - HPEBT_YN: Do you have an EBT card, - HPUBLIC: public housing y/n, - HRNUMWIC: # people receiving WIC - Women, Infants, and Children Nutrition Program, - HRWICYN: was anyone on WIC the prior year?)
#
# Y (HLORENT) = f(union representation)
# Y (HLORENT) = f(union membership)
# ...etc... (assuming it's the same for every variable, please correct me if I'm wrong)
#
#
# ### Hypothesis 2-F: Unions ~ Housing
# Union representation and membership are positively correlated with higher-quality living quarters (H_LIVQRT), which I will have to define on a spectrum from low-high based on the categories encompassed by the living quarters measure (H_LIVQRT).
#
# Y (H_LIVQRT) = f(union representation)
# Y (H_LIVQRT) = f(union membership)
#
# > Q4: How many observations in your model or models (n)?
#
# n = 152,732
#
# > Q5: How many features in your model or models (p)?
#
# Subject to change, since I don't fully comprehend the massive census dataset yet.
#
# H1: 8
# H2: 21
#
# > Q6: Describe the (at least) three methods from class that you will be using in your analyses.
#
# Calculate expected probability distributions for all variables.
#
# Calculate summary statistics to understand relationships better.
#
# Using the pairs() function to look at pairwise scatterplots when appropriate.
# Use linear models to discover significance.
#
# Use multiple linear regression, grouping by categorical variables (e.g. reason for being unemployed, quality of shelter) to separate the different classes of categorical variable, as each is meaningfully different.
#
# Manipulate the data to remove all the variables I'm not interested in with the power of the mighty tidyverse!!
#
# Clean the data (just in case). Could there be a way to clean data to remove outliers?
